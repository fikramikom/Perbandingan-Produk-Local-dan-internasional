# %% [markdown]
# <a href="https://colab.research.google.com/github/fikramikom/Perbandingan-Produk-Local-dan-internasional/blob/main/Visualisasi%20Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
sns.set(style='whitegrid')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/tugas_besar_orbit/hasil_sentimen_converes.csv',  sep=",")
df2 = pd.read_csv('/content/drive/MyDrive/tugas_besar_orbit/hasil_sentimen_aerostreet.csv',  sep=",")

# %%
df1.head()
# Out:
#                                              comment  rating  \
# 0  Alhamdulillah waktu itu lagi ada potongan harg...       5
# 1  Barang sudah dibterima dg baik,  packing rapih...       5
# 2  ahh dapat hrg murah bgt ini mah, good 👌 size n...       5
# 3  Tampilan:sesuai\nWarna:sesuai\n\nProduknya ori...       5
# 4  Alhamdulillah barang nya sudah sampai, cepet b...       5
#
#                                        clean_comment  \
# 0  alhamdulillah potong harga 200k murah barang o...
# 1  barang dibterima dg baik packing rapih tdk pen...
# 2  ahh hrg murah bgt mah good  size nya jg pas bgttt
# 3  tampil sesuai warna sesuai produk ori ga kecew...
# 4  alhamdulillah barang nya sampai cepet banget k...
#
#                                      text_slangwords  \
# 0  alhamdulillah potong harga 200k murah barang o...
# 1  barang dibterima dengan baik packing rapih tid...
# 2  ahh harga murah banget mah good size nya juga ...
# 3  tampil sesuai warna sesuai produk ori ga kecew...
# ...

# %%
df2.head()
# Out:
#                                              comment  rating  \
# 0  Tampilan:tampilan bagus, menarik, kualitas bag...       5
# 1  Tampilan:bagus\nWarna:hitam, sesuai foto\n\nBa...       5
# 2  Tampilan:Bagus\nWarna:Hitam Putih\n\nBagus ban...       5
# 3  Tampilan:Sepatu sneakers\nWarna:Hitam\n\nsanga...       5
# 4  Sepadan dengan Harga:sepadan banget worthit.\n...       5
#
#                                        clean_comment  \
# 0  tampil tampil bagus tarik kualitas bagus harga...
# 1  tampil bagus warna hitam sesuai foto baju sepa...
# 2  tampil bagus warna hitam putih bagus banget fo...
# 3  tampil sepatu sneakers warna hitam cocok keren...
# 4  padan harga padan banget worthit kualitas bagu...
#
#                                      text_slangwords  \
# 0  tampil tampil bagus tarik kualitas bagus harga...
# 1  tampil bagus warna hitam sesuai foto baju sepa...
# 2  tampil bagus warna hitam putih bagus banget fo...
# 3  tampil sepatu sneakers warna hitam cocok keren...
# ...

# %% [markdown]
# # Visualisasi

# %% [markdown]
# ### Visualisasi Pie Chart Respon

# %%
fig, ax = plt.subplots(figsize = (6, 6))
sizes = [count for count in df1['polarity'].value_counts()]
labels = list(df1['polarity'].value_counts().index)
explode = (0, 0)
ax.pie(x = sizes, labels = labels, autopct = '%1.1f%%', explode = explode, textprops={'fontsize': 14})

ax.set_title('Sentimen Analisis Distribusi Sepatu Converse ', fontsize = 16, pad = 20)
plt.show()

fig, ax = plt.subplots(figsize = (6, 6))
sizes = [count for count in df2['polarity'].value_counts()]
labels = list(df2['polarity'].value_counts().index)
explode = (0, 0,)
ax.pie(x = sizes, labels = labels, autopct = '%1.1f%%', explode = explode, textprops={'fontsize': 14})
ax.set_title('Sentimen Analisis Distribusi Sepatu Aerostreet', fontsize = 16, pad = 20)
plt.show()

# %% [markdown]
# ### Visualisasi bar Chart Respon

# %%
# Menghitung jumlah data untuk setiap kategori polarity
sizes = [count for count in df1['polarity'].value_counts()]
labels = list(df1['polarity'].value_counts().index)

# Menggambar diagram batang
plt.figure(figsize=(6, 6))
plt.bar(labels, sizes, color=['green', 'orange', 'red'])  # Mengganti warna batang sesuai kebutuhan
plt.xlabel('Sentimen')
plt.ylabel('Jumlah')
plt.title('Sentimen Analisis Distribusi Sepatu Converse')
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca jika terlalu banyak kategori
plt.show()


# Menghitung jumlah data untuk setiap kategori polarity
sizes = [count for count in df2['polarity'].value_counts()]
labels = list(df2['polarity'].value_counts().index)

# Menggambar diagram batang
plt.figure(figsize=(6, 6))
plt.bar(labels, sizes, color=['green', 'orange', 'red'])  # Mengganti warna batang sesuai kebutuhan
plt.xlabel('Sentimen')
plt.ylabel('Jumlah')
plt.title('Sentimen Analisis Distribusi Sepatu Aerostreet')
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca jika terlalu banyak kategori
plt.show()

# %% [markdown]
# ### Menampilkan Sentimen Positif Sepatu Converse

# %%
pd.set_option('display.max_colwidth', 3000)
positive_comment = df1[df1['polarity'] == 'positive']
positive_comment = positive_comment[['text_slangwords', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=False).reset_index(drop = True)
positive_comment.index += 1
positive_comment[0:10]
# Out:
#                                                                                                                                                                                                                                                                                    text_slangwords  \
# 1                                                                                                                                                              pas acara segala acara nyaman oke kualitas oke mantap banget dapat harga 850 kualitas top ukur 24 5cm pas pakai nomor 5 5 thank you
# 2                                                                                                          padan uang padan kualitas legit original pas acara casual santai barang darat aman selamat harga rupa original pasti mudah mudah awet pakai jangka lama packing aman kualitas ragu lagi
# ...

# %% [markdown]
# ### Menmpilkan Sentimen Negatif Sepatu Convers

# %%
pd.set_option('display.max_colwidth', 3000)
negative_comment = df1[df1['polarity'] == 'negative']
negative_comment = negative_comment[['text_slangwords', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=True)[0:10].reset_index(drop = True)
negative_comment.index += 1
negative_comment[0:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text_slangwords  \
# ...

# %% [markdown]
# ### Menampilkan Sentimen Positif Sepatu Aerostreet

# %%
pd.set_option('display.max_colwidth', 3000)
positive_comment = df2[df2['polarity'] == 'positive']
positive_comment = positive_comment[['text_slangwords', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=False).reset_index(drop = True)
positive_comment.index += 1
positive_comment[0:10]
# Out:
#                                                                                                                                                                                                             text_slangwords  \
# 1   tampil ok warna ok alhamdulillah sepatu suami udh dateng moga suka pas sesuai ukur he seller respon cepat kirim cepat packingan oke ga pakai bubble wrap untung aman smpe rumah tertawa terima kasih seller moga berkah
# 2                   tampil good performa warna elegan sesuai ekspetasi ukur pas aerostreet emang lokal gentar banget deh top kirim cepat mantap padat good momen terima kasih seller aerostreet moga sukses kualitas mantap
# 3                                 jual sepatu sekolah adhitya caesarico distribusi produk luring toko toko sekian jual sepatu sekolah adhitya kembang bisnis jual model tambah variasi produk sepatu jual aerostreet jenama
# ...

# %% [markdown]
# ### Menmpilkan Sentimen Negatif Sepatu Aerostreet

# %%
pd.set_option('display.max_colwidth', 3000)
negative_comment = df2[df2['polarity'] == 'negative']
negative_comment = negative_comment[['text_slangwords', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=True)[0:10].reset_index(drop = True)
negative_comment.index += 1
negative_comment[0:20]
# Out:
#                                                                                                                                                                                                                                                                                                            text_slangwords  \
# 1                                                                         warna hitam tampil kurang bagus tebal tapi yang kurang qc nya teliti jahit depan sedikit saran jahit kendala jeblos loncat overal bagus saja kendala sepatu enak di pakai untuk size pas sih kirim banget iya sampai minggu mana di batalin lagi
# 2                                                                 tampil bagus warna bagus saran yang beli ambil 1 tingkat ukur kaki yang biasa uk 40 ambil uk 41 saran untuk toko baik lagi quality control finishing benang mana untuk harga 100rb an not bad ygy wajib beli yang suka murah riah dengan barang yang oke
# ...

# %% [markdown]
# ### Visualisasi most frequent words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Assuming 'text_slangwords' is the column containing the text data in both datasets
vectorizer = TfidfVectorizer()

# Dataset 1
X1 = vectorizer.fit_transform(df1['text_slangwords'])
tfidf_df1 = pd.DataFrame(X1.toarray(), columns=vectorizer.get_feature_names_out())
bagus_count1 = tfidf_df1['bagus'].sum()
bagus_df1 = pd.DataFrame({'word': ['bagus'], 'count': [bagus_count1]})

# Dataset 2
X2 = vectorizer.fit_transform(df2['text_slangwords'])
tfidf_df2 = pd.DataFrame(X2.toarray(), columns=vectorizer.get_feature_names_out())
bagus_count2 = tfidf_df2['bagus'].sum()
bagus_df2 = pd.DataFrame({'word': ['bagus'], 'count': [bagus_count2]})

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Plot for Dataset 1
sns.barplot(x='count', y='word', data=bagus_df1, ax=axes[0])
axes[0].set_title('Occurrences of "bagus" in Dataset converes')

# Plot for Dataset 2
sns.barplot(x='count', y='word', data=bagus_df2, ax=axes[1])
axes[1].set_title('Occurrences of "bagus" in Dataset aerostreet')

plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


# Visualize most frequent words convers
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df1['text_slangwords'])
tfidf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
tfidf_df = tfidf_df.sum().reset_index(name='jumlah')
tfidf_df = tfidf_df.sort_values('jumlah', ascending=False).head(6)
sns.barplot(x='jumlah', y='index', data=tfidf_df)
plt.title('Most Frequent Words Convers')
plt.show()

# Visualize most frequent words aerostreet
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df2['text_slangwords'])
tfidf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
tfidf_df = tfidf_df.sum().reset_index(name='jumlah')
tfidf_df = tfidf_df.sort_values('jumlah', ascending=False).head(6)
sns.barplot(x='jumlah', y='index', data=tfidf_df)
plt.title('Most Frequent Words aerostreet')
plt.show()

# %% [markdown]
# ### Visualisasi Bigrams

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.util import ngrams
import nltk
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df1 and df2 are your DataFrames containing the 'text_slangwords' column

# Visualize most frequent bigrams in df1
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df1['text_slangwords'])

# Combine words back into text
corpus = df1['text_slangwords'].str.split()

# Generate bigrams
bigrams = [bigram for words in corpus for bigram in list(ngrams(words, 2))]

# Count bigram frequencies
bigram_counts = Counter(bigrams)

# Take top 6 bigrams
top_bigrams = bigram_counts.most_common(6)

# Create DataFrame for top bigrams
bigram_df = pd.DataFrame(top_bigrams, columns=['Bigram', 'Count'])

# Visualize with a bar plot
sns.barplot(x='Count', y='Bigram', data=bigram_df)
plt.title('Most Frequent Bigrams Conversations')
plt.show()

# Visualize most frequent bigrams in df2
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df2['text_slangwords'])

# Combine words back into text
corpus = df2['text_slangwords'].str.split()

# Generate bigrams
bigrams = [bigram for words in corpus for bigram in list(ngrams(words, 2))]

# Count bigram frequencies
bigram_counts = Counter(bigrams)

# Take top 6 bigrams
top_bigrams = bigram_counts.most_common(6)

# Create DataFrame for top bigrams
bigram_df = pd.DataFrame(top_bigrams, columns=['Bigram', 'Count'])

# Visualize with a bar plot
sns.barplot(x='Count', y='Bigram', data=bigram_df)
plt.title('Most Frequent Bigrams Aerostreet')
plt.show()

# %% [markdown]
# ### Visualisasi Trigrams

# %%
# Tokenisasi teks menjadi kata-kata
nltk.download('punkt')  # Memastikan Anda memiliki data tokenisasi

# Visualize most frequent trigrams convers
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df1['text_slangwords'])

# Menggabungkan kata-kata kembali menjadi teks
corpus = df1['text_slangwords'].str.split()

# Menghasilkan trigrams
trigrams = [trigram for words in corpus for trigram in list(ngrams(words, 3))]

# Menghitung frekuensi trigrams
trigram_counts = Counter(trigrams)

# Mengambil 6 trigrams teratas
top_trigrams = trigram_counts.most_common(6)

# Membuat DataFrame untuk trigrams teratas
trigram_df = pd.DataFrame(top_trigrams, columns=['Trigram', 'Count'])

# Visualisasi dengan diagram batang
sns.barplot(x='Count', y='Trigram', data=trigram_df)
plt.title('Most Frequent Trigrams Convers')
plt.show()


# Visualize most frequent trigrams aerostreet
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df2['text_slangwords'])

# Menggabungkan kata-kata kembali menjadi teks
corpus = df2['text_slangwords'].str.split()

# Menghasilkan trigrams
trigrams = [trigram for words in corpus for trigram in list(ngrams(words, 3))]

# Menghitung frekuensi trigrams
trigram_counts = Counter(trigrams)

# Mengambil 6 trigrams teratas
top_trigrams = trigram_counts.most_common(6)

# Membuat DataFrame untuk trigrams teratas
trigram_df = pd.DataFrame(top_trigrams, columns=['Trigram', 'Count'])

# Visualisasi dengan diagram batang
sns.barplot(x='Count', y='Trigram', data=trigram_df)
plt.title('Most Frequent Trigrams Aerostreet')
plt.show()

# %% [markdown]
# # Klasifikasi Model

# %% [markdown]
# ## Menetukan X dan Y

# %%
df2.head()

# %%
# Pisahkan data menjadi fitur (comment) dan label (sentimen)
X = df1['text_preprocessed']
y = df1['polarity']

# %% [markdown]
# ##Extraksi ciri dengan TF IDF

# %%
# Ekstraksi fitur dengan TF-IDF
tfidf = TfidfVectorizer(max_features=200, min_df=17, max_df=0.8 )
X_tfidf = tfidf.fit_transform(X)

# %%
# Konversi hasil ekstraksi fitur menjadi dataframe
features_df = pd.DataFrame(X_tfidf.toarray(), columns=tfidf.get_feature_names_out())

# Menampilkan hasil ekstraksi fitur
features_df
# Out:
#           100  acara      aman     bagus      baik    banget    barang  \
# 0    0.000000    0.0  0.300225  0.000000  0.279785  0.000000  0.203118
# 1    0.274069    0.0  0.000000  0.000000  0.233610  0.000000  0.678382
# 2    0.000000    0.0  0.000000  0.000000  0.000000  0.475552  0.000000
# 3    0.000000    0.0  0.000000  0.156081  0.000000  0.000000  0.000000
# 4    0.000000    0.0  0.000000  0.000000  0.000000  0.328032  0.357683
# ..        ...    ...       ...       ...       ...       ...       ...
# 486  0.000000    0.0  0.000000  0.000000  0.000000  0.756274  0.000000
# 487  0.000000    0.0  0.000000  0.000000  0.000000  0.328418  0.358103
# 488  0.293750    0.0  0.000000  0.000000  0.000000  0.000000  0.181774
# 489  0.000000    0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 490  0.000000    0.0  0.000000  0.000000  0.294522  0.000000  0.000000
#
#          beli  besar  black  ...  sudah  suka    tampil  tapi    terima  \
# ...

# %% [markdown]
# ## Data Split

# %%
# Bagi data menjadi data latih dan data uji
from sklearn.model_selection import train_test_split,GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Data Training dan Data Testing

# %%
# Latih model klasifikasi Naive Bayes
from sklearn.naive_bayes import GaussianNB # Terburuk train 34, test 34
from sklearn.naive_bayes import BernoulliNB #Terbaik train 81, test 76
from sklearn.naive_bayes import MultinomialNB # Terbaik train 80, test 78
from sklearn.naive_bayes import ComplementNB #Terbaik train 82, test 81

naive_bayes = ComplementNB()
naive_bayes.fit(X_train.toarray(), y_train)

# %%
from sklearn.metrics import accuracy_score, precision_score

# Prediksi sentimen pada data uji
y_pred_train = naive_bayes.predict(X_train.toarray())
y_pred_test = naive_bayes.predict(X_test.toarray())

# Evaluasi akurasi model
accuracy_train = accuracy_score(y_pred_train, y_train)
accuracy_test = accuracy_score(y_pred_test, y_test)
print('accuracy_train:', accuracy_train)
print('accuracy_test:', accuracy_test)

# %% [markdown]
# ## Evaluasi Model

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Evaluasi dengan classification report
classification = classification_report(y_test, y_pred_test)
print('Classification Report:')
print(classification)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.66      0.88      0.76       179
#     positive       0.94      0.80      0.86       396
#
#     accuracy                           0.82       575
#    macro avg       0.80      0.84      0.81       575
# weighted avg       0.85      0.82      0.83       575

# %%
# membuat confusion matrix
cm = confusion_matrix(y_test, y_pred_test)

# menampilkan confusion matrix menggunakan heatmap
sns.heatmap(cm, annot=True,fmt='d', cmap='Blues')
plt.title('Confusion Matrix Naive Bayes')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
